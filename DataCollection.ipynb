# %% [markdown]
# ## This module performs Web scraping and obtains list of Diseases & respective Symptoms.

# %%
# Filter & ignore warnings for clear output visualization

import warnings
warnings.filterwarnings("ignore")

# %%
# Install google module for python

# !pip install google
# Out:
# Requirement already satisfied: google in /Users/Manasa/opt/anaconda3/lib/python3.8/site-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in /Users/Manasa/opt/anaconda3/lib/python3.8/site-packages (from google) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/Manasa/opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->google) (2.2.1)

# %%
# Import all necessary packages

import re
import time
import pickle
import string
import requests
from bs4 import BeautifulSoup
from googlesearch import search

# %% [markdown]
# ### Functions to Obtain list of diseases from the website: www.nhp.gov.in

# %%
# Defines a function to obtain diseases list from nhp

def getDiseasesFromNhp():

    # As diseases are ordered alphabetically in the website, we first maintain a list of lower case letters
    lowercase_letters = list(string.ascii_lowercase)

    # Read diseases from the website using the lowercase_letters list
    diseases = []
    base_url = "https://www.nhp.gov.in/disease-a-z/"

    for letter in lowercase_letters:

        # Track progress
        print(" --> Obtaining diseases that start with " + letter)

        # Form the target URL we are interested in
        target_url = base_url + letter

        # Add some sleep time to avoid affecting the performance of the web server as it can be problematic for us
        time.sleep(1)

        # Obtain target page without verifying certificate
        target_page = requests.get(target_url, verify=False)

        # Pull data from the HTML & XML pages by web scraping using BeautifulSoup
        page_contents = BeautifulSoup(target_page.content, "html5lib")

        # Retrieve all diseases from the page. We know the page structure by inspecting the html structure of the page on web
        all_diseases = page_contents.find("div", class_="all-disease")

        # Within the <div>(all-disease), we have a <ul> inside which we have several <a> which contain <li> with disease names
        # So, from the obtained information, we perform futher processing to read the disease names
        for tag in all_diseases.find_all("li"):
            diseases.append(tag.get_text().strip())

        # Obtain set of diseases
        diseases_set1 = set(diseases)
        
    return diseases_set1

# %%
# Defines a function to obtain diseases from pickle file

def getDiseasesFromPickle():
    # We obtain few other diseases too
    other_diseases = None

    # We use pickle to handle data serialization here
    with open("other_diseases_pkl.txt", "rb") as handle:
        other_diseases = pickle.load(handle)

    # Obtain set of diseases
    diseases_set2 = set(other_diseases)
        
    return diseases_set2

# %%
# Defines to a function to obtain final list of diseases

def getFinalDiseases(diseases1, diseases2):
    
    all_diseases_list = list(diseases1.union(diseases2))

    # Sort all the diseases for convenience
    all_diseases_list.sort()                

    # Analysis of individual disease sets we obtained
    len1 = len(diseases1)
    len2 = len(diseases2)
    len_common = len(diseases1.intersection(diseases2))

    # Print analysis results
    print("Diseases1 length: ", len1, " ---- Diseases2 length: ", len2, " ---- Common diseases length: ", len_common)
    
    # print final list of diseases
    #print(all_diseases_list)
    
    return all_diseases_list

# %% [markdown]
# ### Functions to Obtain list of symptoms associated with symptoms from Wikipedia

# %%
# Defines a function to get symptoms for respective disease

def getSymptomsFromWiki(all_diseases):
    
    # Final dictionary of symptoms
    disease_symptoms = {}

    for disease in all_diseases:
        
        print("Currently processing the disease: " + disease)
        
        # Build search query
        search_query = disease + "wikipedia"

        # Search "disease wikipedia" on Google
        for search_result in search(search_query, tld="co.in", stop=10, pause=0.5):

            # Open wikipedia link
            match = re.search(r"wikipedia", search_result)

            filled = 0

            if match:
                wiki_page = requests.get(search_result, verify=False)
                wiki_contents = BeautifulSoup(wiki_page.content, "html5lib")
                
                #print(wiki_contents)

                # Fetch HTML code for "infobox"
                info_table = wiki_contents.find("table", {"class":"infobox"})
                #print(info_table)

                if info_table is not None:
          
                    # Preprocess contents of infobox
                    for row in info_table.find_all("tr"):
                        #print(row)
                                 
                        row_data = row.find("th", {"scope":"row"})
                        #print(row_data)
                        #print("------------------")
                        
                        if row_data is not None:
                            row_data = row_data.get_text()

                            if row_data == "Symptoms":
                                symptom = str(row_data.find("td"))
                                symptom = symptom.replace(".", "")
                                symptom = symptom.replace(";", ",")

                                # Remove bold text
                                symptom=re.sub(r'<b.*?/b>:',',',symptom)

                                # Remove hyperlink
                                symptom=re.sub(r'<a.*?>','',symptom)
                                symptom=re.sub(r'</a>','',symptom)

                                # Remove all the tags
                                symptom=re.sub(r'<[^<]+?>',', ',symptom)

                                # Remove citation text
                                symptom=re.sub(r'\[.*\]','',symptom)
                                symptom=' '.join([x for x in symptom.split() if x != ','])

                                # Update symptoms
                                disease_symptoms[disease] = symptom

                                filled = 1
                                break

                if filled == 1:
                    break
                
    return disease_symptoms

# %%
# Defines a function that does preprocessing on the disease and associated symptoms list 

def saveSymptomsToPickle(disease_symptoms):
    # Remove diseases that are associated with duplicate symptoms list
    temp_list = []
    temp_dict = {}
    count = 0
        
    for key, val in disease_symptoms.items():
        # Here, val is a list pof symptoms associated with the disease
        # So, we check if the same list already exists in the the temporary list we have
        if val not in temp_list:
            temp_dict[key] = val
            temp_list.append(val)    
        
        disease_symptoms = temp_dict
        count = count + 1
    
        # Save the dictionary in a pickle file
        with open("final_disease_symptoms.pickle", "wb") as handle:
            pickle.dump(disease_symptoms, handle, protocol=pickle.HIGHEST_PROTOCOL)
            
    print(count)

# %% [markdown]
# ### Execution steps to Obtain diseases & the symptoms associated with them

# %%
# Obtains consolidated list of diseases (This step takes 8-10 mins to execute)

print("\n--------- OBTAINING LIST OF DISEASES ---------\n")
diseases1 = getDiseasesFromNhp()
diseases2 = getDiseasesFromPickle()
all_diseases = getFinalDiseases(diseases1, diseases2)
# Out:
# --------- OBTAINING LIST OF DISEASES ---------
#
#  --> Obtaining diseases that start with a
#  --> Obtaining diseases that start with b
#  --> Obtaining diseases that start with c
#  --> Obtaining diseases that start with d
#  --> Obtaining diseases that start with e
#  --> Obtaining diseases that start with f
#  --> Obtaining diseases that start with g
#  --> Obtaining diseases that start with h
#  --> Obtaining diseases that start with i
#  --> Obtaining diseases that start with j
#  --> Obtaining diseases that start with k
#  --> Obtaining diseases that start with l
#  --> Obtaining diseases that start with m
#  --> Obtaining diseases that start with n
#  --> Obtaining diseases that start with o
#  --> Obtaining diseases that start with p
#  --> Obtaining diseases that start with q
#  --> Obtaining diseases that start with r
#  --> Obtaining diseases that start with s
#  --> Obtaining diseases that start with t
#  --> Obtaining diseases that start with u
#  --> Obtaining diseases that start with v
#  --> Obtaining diseases that start with w
#  --> Obtaining diseases that start with x
#  --> Obtaining diseases that start with y
#  --> Obtaining diseases that start with z
# Diseases1 length:  302  ---- Diseases2 length:  236  ---- Common diseases length:  48

# %%
# Obtains preprocessed list of symptoms associated with diseases (This step takes 15-20 mins to execute)

print("\n--------- OBTAINING LIST OF DISEASES ---------\n")
disease_symptoms = getSymptomsFromWiki(all_diseases)
# Out:
# --------- OBTAINING LIST OF DISEASES ---------
#
# Currently processing the disease: Abdominal Pain
# Currently processing the disease: Abducens nerve Palsy
# Currently processing the disease: Abnormal uterine bleeding
# Currently processing the disease: Abscess
# Currently processing the disease: Acquired Capillary Haemangioma of Eyelid
# Currently processing the disease: Acquired Immuno Deficiency Syndrome
# Currently processing the disease: Acute encephalitis syndrome
# Currently processing the disease: Adult Inclusion Conjunctivitis
# Currently processing the disease: Airbag Eye Injury
# Currently processing the disease: Alcohol Abuse and Alcoholism
# Currently processing the disease: Alopecia (hair loss)
# Currently processing the disease: Alzheimer
# Currently processing the disease: Alzheimer's Disease
# Currently processing the disease: Amaurosis Fugax
# Currently processing the disease: Amblyopia
# Currently processing the disease: Amoebiasis
# Currently processing the disease: Anaemia
# Currently processing the disease: Anaemia during pregnancy (Maternal anemia)
# Currently processing the disease: Aniseikonia
# Currently processing the disease: Anisometropia
# Currently processing the disease: Ankyloblepharon
# Currently processing the disease: Anotia
# Currently processing the disease: Antepartum hemorrhage (Bleeding in late pregnancy)
# Currently processing the disease: Anthrax
# Currently processing the disease: Anxiety
# Currently processing the disease: Aphakia
# Currently processing the disease: Appendicitis
# Currently processing the disease: Apraxia
# Currently processing the disease: Argyria
# Currently processing the disease: Arthritis
# Currently processing the disease: Asbestos-related diseases
# Currently processing the disease: Aseptic meningitis
# Currently processing the disease: Asthenia
# Currently processing the disease: Asthma
# Currently processing the disease: Astigmatism
# Currently processing the disease: Atherosclerosis
# Currently processing the disease: Athetosis
# Currently processing the disease: Atopic Keratoconjunctivitis
# Currently processing the disease: Atrophy
# Currently processing the disease: Autism
# Currently processing the disease: Avian influenza in humans
# Currently processing the disease: Back Pain
# Currently processing the disease: Bacterial meningitis
# Currently processing the disease: Bad Breath (Halitosis)
# Currently processing the disease: Band Shaped Keratopathy
# Currently processing the disease: Bedsores
# Currently processing the disease: Bell's Palsy
# Currently processing the disease: Benign Essential Blepharospasm
# Currently processing the disease: Beriberi
# Currently processing the disease: Black Death
# Currently processing the disease: Bleeding Gums
# Currently processing the disease: Blepharitis
# Currently processing the disease: Blepharochalasis
# Currently processing the disease: Blindness
# Currently processing the disease: Botulism
# Currently processing the disease: Brain Tumour
# Currently processing the disease: Breast Cancer / Carcinoma
# Currently processing the disease: Breast cancer
# Currently processing the disease: Bronchitis
# Currently processing the disease: Brucellosis
# Currently processing the disease: Bruxism (Teeth Grinding)
# Currently processing the disease: Bubonic plague
# Currently processing the disease: Bunion
# Currently processing the disease: Burns
# Currently processing the disease: Calculi
# Currently processing the disease: Campylobacter infection
# Currently processing the disease: Cancer
# Currently processing the disease: Candidiasis
# Currently processing the disease: Carbon monoxide poisoning
# Currently processing the disease: Carpal Tunnel Syndrome
# Currently processing the disease: Cavernous Haemangioma of Eyelid
# Currently processing the disease: Cavities
# Currently processing the disease: Celiacs disease
# Currently processing the disease: Cerebral palsy
# Currently processing the disease: Cervical cancer
# Currently processing the disease: Chagas disease
# Currently processing the disease: Chalazion
# Currently processing the disease: Chalcosis
# Currently processing the disease: Chancroid
# Currently processing the disease: Chavia
# Currently processing the disease: Chemical Injuries to the Eyes
# Currently processing the disease: Cherubism
# Currently processing the disease: Chickenpox
# Currently processing the disease: Chikungunya Fever
# Currently processing the disease: Child maltreatment (child abuse)
# Currently processing the disease: Childhood Exotropia
# Currently processing the disease: Chlamydia
# Currently processing the disease: Chlamydia trachomatis
# Currently processing the disease: Cholera
# Currently processing the disease: Chordoma
# Currently processing the disease: Chorea
# Currently processing the disease: Chronic fatigue syndrome
# Currently processing the disease: Chronic obstructive pulmonary disease (COPD)
# Currently processing the disease: Circadian rhythm sleep disorder
# Currently processing the disease: Cleft Lip and Cleft Palate
# Currently processing the disease: Coccidioidomycosis
# Currently processing the disease: Colitis
# Currently processing the disease: Colorectal Cancer
# Currently processing the disease: Common cold
# Currently processing the disease: Commotio Retinae
# Currently processing the disease: Computer Vision Syndrome
# Currently processing the disease: Condyloma
# Currently processing the disease: Congenital Capillary Haemangioma of Eyelid
# Currently processing the disease: Congenital anomalies (birth defects)
# Currently processing the disease: Congenital insensitivity to pain with anhidrosis
# Currently processing the disease: Congestive heart disease
# Currently processing the disease: Conjunctival Concretions
# Currently processing the disease: Conjunctivochalasis
# Currently processing the disease: Corneal Abrasion
# Currently processing the disease: Coronary Heart Disease
# Currently processing the disease: Coronary heart disease
# Currently processing the disease: Coronavirus disease 2019 (COVID-19)
# Currently processing the disease: Cough
# Currently processing the disease: Cowpox
# Currently processing the disease: Cretinism
# Currently processing the disease: Crimean Congo haemorrhagic fever (CCHF)
# Currently processing the disease: Crimean-Congo haemorrhagic fever (CCHF)
# Currently processing the disease: Dacryoadenitis
# Currently processing the disease: Dacryocystitis
# Currently processing the disease: Deafness
# Currently processing the disease: Dehydration
# Currently processing the disease: Dementia
# Currently processing the disease: Dengue
# Currently processing the disease: Dengue Fever
# Currently processing the disease: Dermatochalasis
# Currently processing the disease: Diabetes Mellitus
# Currently processing the disease: Diabetes mellitus
# Currently processing the disease: Diabetic Retinopathy
# Currently processing the disease: Diarrhea
# Currently processing the disease: Digit-Sucking (Thumb/ Finger-Sucking)
# Currently processing the disease: Diphtheria
# Currently processing the disease: Disabilities
# Currently processing the disease: Distichiasis
# Currently processing the disease: Double Elevator Palsy
# Currently processing the disease: Down's Syndrome
# Currently processing the disease: Dracunculiasis (guinea-worm disease)
# Currently processing the disease: Duane Retraction Syndrome
# Currently processing the disease: Dysentery
# Currently processing the disease: Ear infection
# Currently processing the disease: Early pregnancy loss
# Currently processing the disease: Ebola
# Currently processing the disease: Ebola Virus Disease (EVD)
# Currently processing the disease: Eclampsia
# Currently processing the disease: Ectopic pregnancy
# Currently processing the disease: Ectropion
# Currently processing the disease: Eczema
# Currently processing the disease: Emphysema
# Currently processing the disease: Encephalitis
# Currently processing the disease: Endometriosis
# Currently processing the disease: Entropion
# Currently processing the disease: Epiblepharon
# Currently processing the disease: Epibulbar Dermoids
# Currently processing the disease: Epicanthus
# Currently processing the disease: Epidemic Keratoconjunctivitis
# Currently processing the disease: Epidemic dropsy
# Currently processing the disease: Epilepsy
# Currently processing the disease: Erectile dysfunctions
# Currently processing the disease: Euryblepharon
# Currently processing the disease: Exposure Keratopathy
# Currently processing the disease: Eyelid Varix
# Currently processing the disease: Factitious Keratoconjunctivitis
# Currently processing the disease: Female genital mutilation
# Currently processing the disease: Fibroids
# Currently processing the disease: Fibromyalgia
# Currently processing the disease: Filamentary Keratitis
# Currently processing the disease: Filariasis
# Currently processing the disease: Floppy Eyelid Syndrome
# Currently processing the disease: Fluorosis
# Currently processing the disease: Food Poisoning
# Currently processing the disease: Fracture (Bone fracture)
# Currently processing the disease: Frey's Syndrome
# Currently processing the disease: Frost Bite
# Currently processing the disease: GERD
# Currently processing the disease: Gaming disorder
# Currently processing the disease: Gangrene
# Currently processing the disease: Gastro-Esophageal Reflux Disease (GERD)
# Currently processing the disease: Gastroenteritis
# Currently processing the disease: Genital herpes
# Currently processing the disease: Giant Papillary Conjunctivitis
# Currently processing the disease: Glaucoma
# Currently processing the disease: Goitre
# Currently processing the disease: Gonorrhea
# Currently processing the disease: Guillain-Barré syndrome
# Currently processing the disease: Gum disease
# Currently processing the disease: HIV
# Currently processing the disease: Haemophilia
# Currently processing the disease: Hand, Foot and Mouth Disease
# Currently processing the disease: Heart disease
# Currently processing the disease: Heat-Related Illnesses and Heat waves
# Currently processing the disease: Helminthiasis (Soil-transmitted helminth infections)
# Currently processing the disease: Hemangioma
# Currently processing the disease: Hepatitis
# Currently processing the disease: Hepatitis A
# Currently processing the disease: Hepatitis B
# Currently processing the disease: Hepatitis C
# Currently processing the disease: Hepatitis D
# Currently processing the disease: Hepatitis E
# Currently processing the disease: Herpes Simplex
# Currently processing the disease: Heterophoria
# Currently processing the disease: High risk pregnancy
# Currently processing the disease: Horner Syndrome
# Currently processing the disease: Human papillomavirus
# Currently processing the disease: Human papillomavirus (HPV) infection and cervical cancer
# Currently processing the disease: Hypermetropia
# Currently processing the disease: Hyperopia
# Currently processing the disease: Hypertension (High Blood pressure)
# Currently processing the disease: Hypertensive Retinopathy
# Currently processing the disease: Hyperthyroidism
# Currently processing the disease: Hypervitaminosis A
# Currently processing the disease: Hypothyroid
# Currently processing the disease: Hypotonia
# Currently processing the disease: Ichthyosis
# Currently processing the disease: Ignious Syndrome
# Currently processing the disease: Impetigo
# Currently processing the disease: Infertility
# Currently processing the disease: Inflammatory Bowel Disease
# Currently processing the disease: Influenza
# Currently processing the disease: Insomnia
# Currently processing the disease: Interstitial cystitis
# Currently processing the disease: Intrauterine growth restriction (IUGR)
# Currently processing the disease: Iritis
# Currently processing the disease: Iron Deficiency Anemia
# Currently processing the disease: Iron-deficiency anemia
# Currently processing the disease: Irritable bowel syndrome
# Currently processing the disease: Japanese Encephalitis
# Currently processing the disease: Jaundice
# Currently processing the disease: Kala-azar/ Leishmaniasis
# Currently processing the disease: Kaposi’s Sarcoma
# Currently processing the disease: Keloids
# Currently processing the disease: Keratoconjunctivitis Sicca (Dry eye syndrome)
# Currently processing the disease: Keratoconus
# Currently processing the disease: Keratoglobus
# Currently processing the disease: Keratosis Pilaris
# Currently processing the disease: Kidney stone disease
# Currently processing the disease: Kuru
# Currently processing the disease: Kwashiorkor
# Currently processing the disease: Kyasanur forest disease
# Currently processing the disease: Lagophthalmos
# Currently processing the disease: Laryngitis
# Currently processing the disease: Lead poisoning
# Currently processing the disease: Legionellosis
# Currently processing the disease: Leishmaniasis
# Currently processing the disease: Leishmaniasis/ Kala-azar
# Currently processing the disease: Leprosy
# Currently processing the disease: Leptospirosis
# Currently processing the disease: Leukemia
# Currently processing the disease: Lice
# Currently processing the disease: Lichen Planus
# Currently processing the disease: Lid Imbrication Syndrome
# Currently processing the disease: Ligneous Conjunctivitis
# Currently processing the disease: Limbtoosa
# Currently processing the disease: Listeriosis
# Currently processing the disease: Loiasis
# Currently processing the disease: Long COVID/Post-COVID conditions
# Currently processing the disease: Low Vision and VisuaI Aids
# Currently processing the disease: Lung cancer
# Currently processing the disease: Lupus erythematosus
# Currently processing the disease: Lyme disease
# Currently processing the disease: Lymphoedema
# Currently processing the disease: Lymphogranuloma venereum
# Currently processing the disease: Lymphoma
# Currently processing the disease: Mad cow disease
# Currently processing the disease: Madarosis
# Currently processing the disease: Malaria
# Currently processing the disease: Malocclusion
# Currently processing the disease: Marburg fever
# Currently processing the disease: Mastitis
# Currently processing the disease: Mattticular syndrome
# Currently processing the disease: Measles
# Currently processing the disease: Measles(Khasra)
# Currently processing the disease: Melanoma
# Currently processing the disease: Meningitis
# Currently processing the disease: Metastatic cancer
# Currently processing the disease: Microcephaly
# Currently processing the disease: Middle East respiratory syndrome coronavirus (MERS‐CoV)
# Currently processing the disease: Migraine
# Currently processing the disease: Mononucleosis
# Currently processing the disease: Mooren's Ulcer
# Currently processing the disease: Morquio Syndrome
# Currently processing the disease: Mouth Breathing
# Currently processing the disease: Mouth Ulcers
# Currently processing the disease: Mucormycosis
# Currently processing the disease: Multiple myeloma
# Currently processing the disease: Multiple sclerosis
# Currently processing the disease: Mumps
# Currently processing the disease: Muscular dystrophy
# Currently processing the disease: Myasthenia gravis
# Currently processing the disease: Myelitis
# Currently processing the disease: Myocardial Infarction (Heart Attack)
# Currently processing the disease: Myoclonus
# Currently processing the disease: Myopia
# Currently processing the disease: Myxedema
# Currently processing the disease: Narcolepsy
# Currently processing the disease: Nasal Polyps
# Currently processing the disease: Nausea and Vomiting of Pregnancy and  Hyperemesis gravidarum
# Currently processing the disease: Necrotizing Fasciitis
# Currently processing the disease: Neonatal Conjunctivitis
# Currently processing the disease: Neonatal Respiratory Disease Syndrome(NRDS)
# Currently processing the disease: Neoplasm
# Currently processing the disease: Neuralgia
# Currently processing the disease: Neurotrophic Keratopathy
# Currently processing the disease: Night blindness
# Currently processing the disease: Nipah virus infection
# Currently processing the disease: Non-gonococcal urethritis
# Currently processing the disease: Nonalcoholic fatty liver disease(NAFLD)
# Currently processing the disease: Obesity
# Currently processing the disease: Obsessive Compulsive Disorder
# Currently processing the disease: Ocular Graft-versus-host Disease
# Currently processing the disease: Oral Cancer
# Currently processing the disease: Orbital Cavernous Haemangioma
# Currently processing the disease: Orbital Dermoid
# Currently processing the disease: Orbital Fat Prolapse
# Currently processing the disease: Orbital Haemangiopericytoma
# Currently processing the disease: Orbital Lymphangioma
# Currently processing the disease: Orbital Solitary Fibrous Tumour
# Currently processing the disease: Orbital Varix
# Currently processing the disease: Osteoarthritis
# Currently processing the disease: Osteomyelitis
# Currently processing the disease: Osteoporosis
# Currently processing the disease: Otitis
# Currently processing the disease: Otitis Media
# Currently processing the disease: Palindromic rheumatism
# Currently processing the disease: Paratyphoid fever
# Currently processing the disease: Parkinson's Disease
# Currently processing the disease: Pellucid Marginal Degeneration
# Currently processing the disease: Pelvic inflammatory disease
# Currently processing the disease: Perennial Allergic Conjunctivitis
# Currently processing the disease: Pericarditis
# Currently processing the disease: Periodontal disease
# Currently processing the disease: Peritonitis
# Currently processing the disease: Pertussis
# Currently processing the disease: Pharyngoconjunctival Fever
# Currently processing the disease: Phlyctenular Keratoconjunctivitis
# Currently processing the disease: Photophthalmia
# Currently processing the disease: Pilia
# Currently processing the disease: Pinguecula
# Currently processing the disease: Plague
# Currently processing the disease: Pneumonia
# Currently processing the disease: Poliomyelitis
# Currently processing the disease: Polycystic ovary syndrome (PCOS)
# Currently processing the disease: Porphyria
# Currently processing the disease: Post Menopausal Bleeding
# Currently processing the disease: Post Polio Syndrome
# Currently processing the disease: Post-herpetic neuralgia
# Currently processing the disease: Postpartum depression/ Perinatal depression
# Currently processing the disease: Postpartum haemorrhage
# Currently processing the disease: Preeclampsia
# Currently processing the disease: Premenstrual syndrome
# Currently processing the disease: Presbyopia
# Currently processing the disease: Preterm birth
# Currently processing the disease: Progeria
# Currently processing the disease: Prostatitis
# Currently processing the disease: Pseudophakia
# Currently processing the disease: Pseudostrabismus
# Currently processing the disease: Psittacosis
# Currently processing the disease: Psoriasis
# Currently processing the disease: Pterygium
# Currently processing the disease: Pubic lice
# Currently processing the disease: Puerperal sepsis
# Currently processing the disease: Pulmonary embolism
# Currently processing the disease: Q Fever
# Currently processing the disease: Ques fever
# Currently processing the disease: Quinsy
# Currently processing the disease: Rabies
# Currently processing the disease: Ramsay-Hunt Syndrome
# Currently processing the disease: Rare diseases
# Currently processing the disease: Raynaud's Phenomenon
# Currently processing the disease: Recurrent Corneal Erosion Syndrome
# Currently processing the disease: Repetitive strain injury
# Currently processing the disease: Retinopathy of Prematurity
# Currently processing the disease: Rheumatic fever
# Currently processing the disease: Rheumatic fever and rheumatic heart disease
# Currently processing the disease: Rheumatic heart
# Currently processing the disease: Rheumatism
# Currently processing the disease: Rheumatoid arthritis
# Currently processing the disease: Rickets
# Currently processing the disease: Rift Valley fever
# Currently processing the disease: Rocky Mountain spotted fever
# Currently processing the disease: Rubella
# Currently processing the disease: SARS
# Currently processing the disease: SIDS
# Currently processing the disease: Salmonellosis
# Currently processing the disease: Salzmann's Nodular Degeneration
# Currently processing the disease: Sarcoidosis
# Currently processing the disease: Sarcoma
# Currently processing the disease: Scabies
# Currently processing the disease: Scarlet fever
# Currently processing the disease: Schizophrenia
# Currently processing the disease: Sciatica
# Currently processing the disease: Scleroderma
# Currently processing the disease: Scrapie
# Currently processing the disease: Scrub Typhus
# Currently processing the disease: Scurvy
# Currently processing the disease: Seasonal Allergic Conjunctivitis
# Currently processing the disease: Sepsis
# Currently processing the disease: Septicemia
# Currently processing the disease: Severe Acute Respiratory Syndrome (SARS)
# Currently processing the disease: Sexually transmitted infections (STIs)
# Currently processing the disease: Shaken Baby Syndrome
# Currently processing the disease: Shigellosis
# Currently processing the disease: Shin splints
# Currently processing the disease: Shingles
# Currently processing the disease: Sickle-cell anemia
# Currently processing the disease: Siderosis
# Currently processing the disease: Siderosis Bulbi
# Currently processing the disease: Silicosis
# Currently processing the disease: Smallpox
# Currently processing the disease: Solar Retinopathy
# Currently processing the disease: Spheroidal Degeneration
# Currently processing the disease: Spinal cord Injury
# Currently processing the disease: Steatoblepharon
# Currently processing the disease: Stevens-Johnson syndrome
# Currently processing the disease: Stomach flu
# Currently processing the disease: Stomach ulcers
# Currently processing the disease: Strabismus
# Currently processing the disease: Strep throat
# Currently processing the disease: Streptococcal infection
# Currently processing the disease: Stroke
# Currently processing the disease: Sub-conjunctival Haemorrhage
# Currently processing the disease: Substance abuse
# Currently processing the disease: Superior Limbic Keratoconjunctivitis
# Currently processing the disease: Swine Flu
# Currently processing the disease: Swine influenza
# Currently processing the disease: Synovitis
# Currently processing the disease: Syphilis
# Currently processing the disease: Taeniasis
# Currently processing the disease: Taeniasis/cysticercosis
# Currently processing the disease: Tay-Sachs disease
# Currently processing the disease: Tennis elbow
# Currently processing the disease: Teratoma
# Currently processing the disease: Terrien's Marginal Degeneration
# Currently processing the disease: Tetanus
# Currently processing the disease: Thalassaemia
# Currently processing the disease: Thermal Injuries to the Eye
# Currently processing the disease: Thrush
# Currently processing the disease: Thymoma
# Currently processing the disease: Tinnitus
# Currently processing the disease: Tonsillitis
# Currently processing the disease: Tooth Sensitivity
# Currently processing the disease: Tooth decay
# Currently processing the disease: Toxic Keratoconjunctivitis
# Currently processing the disease: Toxic shock syndrome
# Currently processing the disease: Trachoma
# Currently processing the disease: Traumatic Hyphaema
# Currently processing the disease: Trichiasis
# Currently processing the disease: Trichinosis
# Currently processing the disease: Trichomoniasis
# Currently processing the disease: Trisomy
# Currently processing the disease: Trochlear Nerve Palsy
# Currently processing the disease: Tuberculosis
# Currently processing the disease: Tularemia
# Currently processing the disease: Tumor
# Currently processing the disease: Tungiasis
# Currently processing the disease: Turners Syndrome
# Currently processing the disease: Typhoid / Enteric Fever
# Currently processing the disease: Typhoid fever
# Currently processing the disease: Typhus
# Currently processing the disease: Ulcerative Colitis
# Currently processing the disease: Ulcerative colitis
# Currently processing the disease: Ulcers
# Currently processing the disease: Uremia
# Currently processing the disease: Urticaria
# Currently processing the disease: Uveitis
# Currently processing the disease: Varicella
# Currently processing the disease: Varicose Veins
# Currently processing the disease: Varicose veins
# Currently processing the disease: Vasovagal syncope
# Currently processing the disease: Vernal Keratoconjunctivitis
# Currently processing the disease: Viral fever
# Currently processing the disease: Viral meningitis
# Currently processing the disease: Vitamin B12 Deficiency
# Currently processing the disease: Vitiligo
# Currently processing the disease: Von Hippel-Lindau disease
# Currently processing the disease: Warkany syndrome
# Currently processing the disease: Warts
# Currently processing the disease: Watkins
# Currently processing the disease: Welding-arc Maculopathy
# Currently processing the disease: West Nile fever
# Currently processing the disease: Whooping Cough/Pertussis
# Currently processing the disease: Xanthelasma
# Currently processing the disease: Xerophthalmia
# Currently processing the disease: Yaws
# Currently processing the disease: Yellow Fever
# Currently processing the disease: Yellow fever
# Currently processing the disease: Yersiniosis
# Currently processing the disease: Zika virus disease
# Currently processing the disease: flu
# Currently processing the disease: lactose intolerance
# Currently processing the disease: papilloedema
# Currently processing the disease: pneumonia
# 1

# %%
saveSymptomsToPickle(disease_symptoms)
# Out:
# 366
